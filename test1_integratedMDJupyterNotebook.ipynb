# %%
import py3Dmol
import MDAnalysis as mda
from MDAnalysisTests.datafiles import PSF, DCD
from MDAnalysis.analysis import rms
from rdkit import Chem
from pathlib import Path
import matplotlib.pyplot as plt

# %%
#INPUT: path to folder of inhibitor PDBs, path to folder of HIV mutation PDBs, path to folder of trajectory files (DO WE NEED MORE THAN 1?), template PDB to orient models
def createModels(inhibitorFolderPath, HIVFolderPath, trajectoryFolderPath, templatePDBFile):
    for path in Path(inhibitorFolderPath).iterdir():
        for path in Path(HIVFolderPath).iterdir():
            # create a model
            # store model in structure
            # compare to multiple trajectory files?

# %%
# TESTING directory iteration
testPath =r"C:\Users\benmm\OneDrive\Desktop\PDBfolder"
for path in Path(testPath).iterdir():
    with open(path, "r") as file:
        view = py3Dmol.view(path)
        view.setStyle({'cartoon': {'color': 'spectrum'}})
        view.zoomTo()
        view.show()
# Out:
# <div id="3dmolviewer_1776791886407111"  style="position: relative; width: 640px; height: 480px;">
#         <p id="3dmolwarning_1776791886407111" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
# ...

# %%
#INPUT: {PDBfileName}.pdb
#OUTPUT: Protein model, style and other specifics TBD
def viewPDBCartoon(PDBfileName):
    view = py3Dmol.view(query='pdb:'+PDBfileName)
    view.setStyle({'cartoon': {'color': 'spectrum'}})
    view.zoomTo()
    view.show()
    
viewPDBCartoon('1HVR')

# %%
#INPUT: Convert PDB file to SMILES string
#OUTPUT: string in SMILES format of PDB
def convertPDBToSmiles(PDBfile):
    mol = Chem.MolFromPDBFile(PDBfile)
    return Chem.MolToSmiles(mol)

# %%
view = py3Dmol.view(query='pdb:comp_all')
view.setStyle({'cartoon': {'color': 'spectrum'}})
view.zoomTo()
view.show()

# %%
view = py3Dmol.view(query='pdb:1HVR')
view.setStyle({'cartoon': {'color': 'spectrum'}})
view.addStyle({'hetflag': True}, {'stick': {}})
view.zoomTo()
view.show()

# %%
#example trajectory
#load a sample molecular dynamics system (topology + trajectory)
#PSF is topology file(atoms, bonds)
#DCD is = trajectory file
u = mda.Universe(PSF, DCD)


# Create an RMSD analysis object
# - u (first argument) the trajectory being analyzed
# - u (second argument): is the refrence structure which is the same system
# - select="protein and name CA" because thi9s is the backbone and it limits outside noise from 
#   -> reduces noise and tracks overall protein backbone movement
# - ref_frame=0: use the first frame of the trajectory as the reference
R = rms.RMSD(u, u, select="protein and name CA", ref_frame=0)
R.run()

rmsd_data = R.results.rmsd

# Extract the computed RMSD results
# The output is a NumPy array with columns:
# [frame index, time (ps), RMSD (Å)]
plt.plot(rmsd_data[:,1], rmsd_data[:,2])
plt.xlabel("Time")
plt.ylabel("RMSD (Å)")
plt.title("RMSD Example")
plt.show()

# %%
print(PSF)
print(DCD)
